# %% [markdown]
# ## Data Preprocessing

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path

# %%
# Load initial data
initial_data = pd.read_csv("data/meteorology_dataset.csv")
initial_data.columns = initial_data.columns.str.strip()

# %% [markdown]
# ### Understanding the Data

# %%
# Display types of the columns~
print("Data types of each column:")
print(initial_data.dtypes)
# Number of values in the dataset
print("\nNumber of values in the dataset:")
print(initial_data.count())
# Check for missing values
print("\nMissing values per column:")
print(initial_data.isnull().sum())
# Out:
# Data types of each column:
# location                    str
# time                        str
# temperature_2m          float64
# relative_humidity_2m      int64
# dew_point_2m            float64
# rain                    float64
# cloud_cover               int64
# cloud_cover_low           int64
# cloud_cover_mid           int64
# cloud_cover_highh         int64
# wind_speed_10m          float64
# wind_direction_10m        int64
# wind_gusts_10m          float64
# wind_direction_100m       int64
# wind_speed_100m         float64
# pressure_msl            float64
# surface_pressure        float64
# dtype: object
#
# Number of values in the dataset:
# location                158112
# time                    158112
# temperature_2m          158112
# relative_humidity_2m    158112
# dew_point_2m            158112
# rain                    158112
# cloud_cover             158112
# cloud_cover_low         158112
# cloud_cover_mid         158112
# cloud_cover_highh       158112
# ...

# %% [markdown]
# ### Checking for Errors and Outliers

# %%
# Duplicates Check
print("\nNumber of duplicate rows in the dataset:")
print(initial_data.duplicated().sum())
# Out:
# Number of duplicate rows in the dataset:
# 0

# %% [markdown]
# ### Data per District

# %%
# Amount of data per district (location)
print("\nNumber of entries per location:")
print(initial_data["location"].value_counts())
# Out:
# Number of entries per location:
# location
# Aveiro              8784
# Beja                8784
# Braga               8784
# Bragança            8784
# Castelo Branco      8784
# Coimbra             8784
# Évora               8784
# Faro                8784
# Guarda              8784
# Leiria              8784
# Lisboa              8784
# Portalegre          8784
# Porto               8784
# Santarém            8784
# Setúbal             8784
# Viana do Castelo    8784
# Vila Real           8784
# Viseu               8784
# Name: count, dtype: int64
